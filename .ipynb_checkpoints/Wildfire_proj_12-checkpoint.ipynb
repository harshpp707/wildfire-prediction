# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('wildfire_train.csv')

# %%
X = dataset[['avg_dry_bulb_temperature', 'avg_dew_point','avg_relative_humidity','avg_rain_mm','avg_snow_cm','avg_hail_mm','avg_precipitation_mm','avg_wind_speed_kmh','avg_wind_gust_kmh','avg_wind_azimuth','avg_ffmc','avg_dmc','avg_dc','avg_isi','avg_bui','avg_fwi','avg_edr']]
Y = dataset[['is_fire']]

# %%
wildfire_data = wildfire_data_raw[['avg_dry_bulb_temperature', 'avg_dew_point','avg_relative_humidity','avg_rain_mm','avg_snow_cm','avg_hail_mm','avg_precipitation_mm','avg_wind_speed_kmh','avg_wind_gust_kmh','avg_wind_azimuth','avg_ffmc','avg_dmc','avg_dc','avg_isi','avg_bui','avg_fwi','avg_edr','is_fire']]

# %%
wildfire_data.dropna()
# Out:
#         avg_dry_bulb_temperature  avg_dew_point  avg_relative_humidity  \
# 52                      9.444444       1.055556              57.166667
# 53                     13.888889       3.777778              53.944444
# 61                     22.166667       9.111111              44.388889
# 63                     13.600000      -3.600000              31.133333
# 66                     12.294118       2.000000              50.058824
# ...                          ...            ...                    ...
# 106813                  7.360000       3.720000              77.720000
# 106814                 11.880000       5.160000              63.082000
# 106829                 10.225000      -2.512500              41.001250
# 106906                 -9.150000     -11.000000              81.500000
# 107225                 11.175000      -4.750000              31.500000
#
#         avg_rain_mm  avg_snow_cm  avg_hail_mm  avg_precipitation_mm  \
# ...

# %%
X = wildfire_data_raw[['avg_dry_bulb_temperature', 'avg_dew_point','avg_relative_humidity','avg_rain_mm','avg_snow_cm','avg_hail_mm','avg_precipitation_mm','avg_wind_speed_kmh','avg_wind_gust_kmh','avg_wind_azimuth','avg_ffmc','avg_dmc','avg_dc','avg_isi','avg_bui','avg_fwi','avg_edr']]
Y = wildfire_data_raw['is_fire']

# %%
X
# Out:
#         avg_dry_bulb_temperature  avg_dew_point  avg_relative_humidity  \
# 0                      20.294118       1.058824              28.058824
# 1                      19.588235      -1.882353              24.470588
# 2                       1.882353       1.705882              97.705882
# 3                       4.411765       1.058824              80.882353
# 4                      16.647059       5.235294              48.588235
# ...                          ...            ...                    ...
# 107330                  5.300000      -6.000000              41.000000
# 107331                  4.600000      -9.000000              35.000000
# 107332                  1.400000     -11.000000              37.000000
# 107333                  4.900000      -7.000000              41.000000
# 107334                  1.500000      -6.500000              52.000000
#
#         avg_rain_mm  avg_snow_cm  avg_hail_mm  avg_precipitation_mm  \
# ...

# %%
Y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 107330    0
# 107331    0
# 107332    0
# 107333    0
# 107334    0
# Name: is_fire, Length: 107335, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.25,random_state=0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Fitting Logistic Regression to the Training set
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\HARSHP~1\ANACON~2\Library\bin/ipykernel_18836/170032164.py in <module>
#       2 from sklearn.linear_model import LogisticRegression
#       3 classifier = LogisticRegression(random_state = 0)
# ----> 4 classifier.fit(X_train, Y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1342             _dtype = [np.float64, np.float32]
#    1343
# -> 1344         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
# ...

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, y_pred)

# %%
cm
# Out:
# array([[8192,    0],
#        [   0, 1832]], dtype=int64)

# %%
# Fitting K-NN to the Training set
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier()

# %%
# Predicting the Test set results
y_pred_knn = classifier.predict(X_test)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm_knn = confusion_matrix(Y_test, y_pred_knn)

# %%
cm_knn
# Out:
# array([[8191,    1],
#        [  18, 1814]], dtype=int64)
